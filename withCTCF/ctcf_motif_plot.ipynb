# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import altair as alt

df=pd.read_csv("ctcf_motif.txt", sep="\t")
df1 = df[df['Class']=="CUT&Tag as Ref."]

alt.Chart(df1).mark_bar().encode(
    x='Type:O',
    y='sum(PCT):Q',
    color = alt.Color('Type',scale=alt.Scale(domain=['typ1', 'typ2', 'typ3', 'typ4'],range=['#051181', '#fb3c3c', '#128b8e',"#feb64a"])),
    column='Sample:N'
)
# Out:
# alt.Chart(...)

# %%
df2 = df[df['Class']=="HiTag-1D peak as Ref."]

x = alt.Chart(df2).mark_bar().encode(
    x='Type:O',
    y='sum(PCT):Q',
    color = alt.Color('Type',scale=alt.Scale(domain=['typ1', 'typ2', 'typ3', 'typ4'],range=['#051181', '#fb3c3c', '#128b8e',"#feb64a"])),
    column='Sample:N'
)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import altair as alt

df=pd.read_csv("ctcf_motif.txt", sep="\t")
df1 = df[df['Class']=="CUT&Tag as Ref."]

alt.Chart(df1).mark_bar().encode(
    x='Sample:O',
    y='sum(PCT):Q',
    color = alt.Color('Sample',scale=alt.Scale(domain=['N3', 'N4', 'N5'],range=['#051181', '#fb3c3c', '#128b8e'])),
    column='Type:N'
)
# Out:
# alt.Chart(...)

# %%
df2 = df[df['Class']=="HiTag-1D peak as Ref."]

x = alt.Chart(df2).mark_bar().encode(
    x='Sample:O',
    y='sum(PCT):Q',
    color = alt.Color('Sample',scale=alt.Scale(domain=['N3', 'N4', 'N5'],range=[ '#3366cc',"#e7475e",'#248888'])),
    column='Type:N'
)

x
# Out:
# alt.Chart(...)

# %%
df
# Out:
#     Type   PCT                  Class Sample
# 0   typ1  0.05        CUT&Tag as Ref.     N3
# 1   typ1  0.05        CUT&Tag as Ref.     N4
# 2   typ1  0.04        CUT&Tag as Ref.     N5
# 3   typ1  0.08  HiTag-1D peak as Ref.     N3
# 4   typ1  0.07  HiTag-1D peak as Ref.     N4
# 5   typ1  0.06  HiTag-1D peak as Ref.     N5
# 6   typ2  0.08        CUT&Tag as Ref.     N3
# 7   typ2  0.08        CUT&Tag as Ref.     N4
# 8   typ2  0.08        CUT&Tag as Ref.     N5
# 9   typ2  0.10  HiTag-1D peak as Ref.     N3
# 10  typ2  0.10  HiTag-1D peak as Ref.     N4
# 11  typ2  0.09  HiTag-1D peak as Ref.     N5
# 12  typ3  0.08        CUT&Tag as Ref.     N3
# 13  typ3  0.07        CUT&Tag as Ref.     N4
# 14  typ3  0.07        CUT&Tag as Ref.     N5
# 15  typ3  0.09  HiTag-1D peak as Ref.     N3
# 16  typ3  0.09  HiTag-1D peak as Ref.     N4
# 17  typ3  0.08  HiTag-1D peak as Ref.     N5
# 18  typ4  0.80        CUT&Tag as Ref.     N3
# 19  typ4  0.80        CUT&Tag as Ref.     N4
# ...
